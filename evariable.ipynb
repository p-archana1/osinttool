# %% [markdown]
# <a href="https://colab.research.google.com/github/p-archana1/osinttool/blob/main/evariable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # variable

# %%
a = 2
print(a)
# Out:
# 2

# %%
b = 3.5
print(b)
# Out:
# 3.5

# %%
c = True
d = "archana"
print(c)
print(d)
# Out:
# True
# archana

# %%
name = "archana"
print("Welcome",name)
# Out:
# Welcome archana

# %%
a = 2
b = 3

print(a+b)
# Out:
# 5

# %% [markdown]
# # Dynamic Typing
# a = 7 #int
# # Static Typing
# int a = 7  #c, C++, java

# %% [markdown]
# # Dynamic Binding
# a = 5
# print(a)
# a = "archana"
# print(a)

# %%
# Dynamic Binding
a = 5
print(a)
a = "archana"
print(a)

# Static Binding

#int a = 7

#str a = "archana"
# Out:
# 5
# archana

# %%
a = 1
b = 2
c = 3

print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a = 5
b = 5
c = 5

print(a,b,c)
# Out:
# 5 5 5

# %%
a=b=c = 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# ![39keywords.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **Identifiers**

# %%
name = "archana"
a = 1

# %%
# You can't start with a digit

1name = "archana"
# Out:
#   File "<ipython-input-17-cdea10a473bc>", line 3
#     1name = "archana"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "archana"

# %%
# You can't use any special chars except _

*name = "archana"
# Out:
#   File "<ipython-input-20-86d480cf401d>", line 3
#     *name = "archana"
#     ^
# SyntaxError: starred assignment target must be in a list or tuple

# %%
name* = "archana"
# Out:
#   File "<ipython-input-21-16623d07e205>", line 1
#     name* = "archana"
#           ^
# SyntaxError: invalid syntax

# %%
name@ = "archana"
# Out:
#   File "<ipython-input-22-c35eee1d0b97>", line 1
#     name@ = "archana"
#           ^
# SyntaxError: invalid syntax

# %%
_name = "archana"

# %%
name_ = "archana"

# %%
_ = "archana"
